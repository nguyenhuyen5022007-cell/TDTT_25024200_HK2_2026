# %% [markdown]
# ### Bài 1:
# in ra dòng chữ "Hello world!". Dùng một lệnh print duy nhất
#
# in ra dòng chữ "Hello world!". Dùng hai lệnh print duy nhất

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Hello", end = " ")
print("world")
# Out:
# Hello world

# %% [markdown]
# \t = tab
#
#  \n = xuống dòng
#
#  end như thường là xuống dòng

# %% [markdown]
# ### W2A2 [User Input]
#
# Hàm input() trong Python là một hàm dùng để nhận dữ liệu từ người dùng thông qua bàn
# phím, hàm này luôn trả về dữ liệu kiểu chuỗi (str).
# Viết chương trình nhận đầu vào là tên người từ bàn phím và in ra màn hình lời chào tương
# ứng.

# %%
name = input()
print("Chào bạn", name)
# Out:
# Chào bạn gsfgsht

# %% [markdown]
# name = input("Ban hay nhap mot cai ten nguoi: ")
#
# ()có thể có hoặc không

# %% [markdown]
# ### W2A3 [ModAndDiv]
# Viết chương trình nhận vào hai số nguyên a, b từ bàn phím. In ra tổng, hiệu, tích, phần
# nguyên, phần dư và kết quả chia thực của phép chia a cho b (lấy đến 2 chữ số phần thập
# phân) theo định dạng đúng của output

# %%
a = int(input())
b = int(input())
print(a +b*- b)
# Out:
# -74
